# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
car = pd.read_csv("C:/Users/priya/Desktop/car prediction price.csv")
car
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
#to show top 5 rows data
car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
#car information
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
#to get last 5 rows data
car.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
# to get shape of data
car.shape
# Out:
# (205, 26)

# %%
#unique
car['fueltype'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
# to check missing values 
car.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
import seaborn as sns
sns.boxplot(car['price'])
# Out:
# <Axes: >

# %%
#to check categorize data
print(car.doornumber.value_counts())
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
inputs=car.drop(['CarName',"doornumber","carbody","drivewheel","enginelocation","wheelbase","symboling","aspiration","enginesize","fuelsystem","boreratio","stroke","compressionratio","horsepower","peakrpm","citympg","highwaympg","enginetype","cylindernumber"],axis='columns') 
target=car.price
target
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
#encoding the categorized data fueltype
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()   #numeric
inputs['fueltype_n']=le.fit_transform(inputs['fueltype'])
inputs['transmission_n']=le.fit_transform(inputs['carheight']) 
inputs
# Out:
#      car_ID fueltype  carlength  carwidth  carheight  curbweight    price  \
# 0         1      gas      168.8      64.1       48.8        2548  13495.0
# 1         2      gas      168.8      64.1       48.8        2548  16500.0
# 2         3      gas      171.2      65.5       52.4        2823  16500.0
# 3         4      gas      176.6      66.2       54.3        2337  13950.0
# 4         5      gas      176.6      66.4       54.3        2824  17450.0
# ..      ...      ...        ...       ...        ...         ...      ...
# 200     201      gas      188.8      68.9       55.5        2952  16845.0
# 201     202      gas      188.8      68.8       55.5        3049  19045.0
# 202     203      gas      188.8      68.9       55.5        3012  21485.0
# 203     204   diesel      188.8      68.9       55.5        3217  22470.0
# 204     205      gas      188.8      68.9       55.5        3062  22625.0
#
#      fueltype_n  transmission_n
# 0             1               1
# ...

# %%
inputs_n=inputs.drop(['fueltype'],axis='columns')
inputs_n
# Out:
#      car_ID  carlength  carwidth  carheight  curbweight    price  fueltype_n  \
# 0         1      168.8      64.1       48.8        2548  13495.0           1
# 1         2      168.8      64.1       48.8        2548  16500.0           1
# 2         3      171.2      65.5       52.4        2823  16500.0           1
# 3         4      176.6      66.2       54.3        2337  13950.0           1
# 4         5      176.6      66.4       54.3        2824  17450.0           1
# ..      ...        ...       ...        ...         ...      ...         ...
# 200     201      188.8      68.9       55.5        2952  16845.0           1
# 201     202      188.8      68.8       55.5        3049  19045.0           1
# 202     203      188.8      68.9       55.5        3012  21485.0           1
# 203     204      188.8      68.9       55.5        3217  22470.0           0
# 204     205      188.8      68.9       55.5        3062  22625.0           1
#
#      transmission_n
# 0                 1
# ...

# %% [markdown]
# splitting data

# %%
from sklearn import linear_model
from sklearn import metrics
model=linear_model.LinearRegression()

# %%
model.fit(inputs_n,target)
# Out:
# LinearRegression()

# %%
pred=model.predict([[201,188.8,68.9,55.5,2952,16845.0,1,34]])
print(pred)
# Out:
# [16845.]
# D:\New folder\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
car
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...
